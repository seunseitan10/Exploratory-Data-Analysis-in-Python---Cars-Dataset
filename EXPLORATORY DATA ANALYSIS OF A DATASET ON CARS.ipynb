# %% [markdown]
# # EXPLORATORY DATA ANALYSIS IN PYTHON

# %%
#importing python libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set(color_codes=True)

# %%
#loading the dataset
data = pd.read_csv(r"C:\Users\REPTON\Desktop\Seun\cars.csv")

# %%
#reading the data
data
# Out:
#       manufacturer_name  model_name transmission   color  odometer_value  \
# 0                Subaru     Outback    automatic  silver          190000
# 1                Subaru     Outback    automatic    blue          290000
# 2                Subaru    Forester    automatic     red          402000
# 3                Subaru     Impreza   mechanical    blue           10000
# 4                Subaru      Legacy    automatic   black          280000
# ...                 ...         ...          ...     ...             ...
# 38526          Chrysler         300    automatic  silver          290000
# 38527          Chrysler  PT Cruiser   mechanical    blue          321000
# 38528          Chrysler         300    automatic    blue          777957
# 38529          Chrysler  PT Cruiser   mechanical   black           20000
# 38530          Chrysler     Voyager    automatic  silver          297729
#
#        year_produced engine_fuel  engine_has_gas engine_type  engine_capacity  \
# ...

# %%
#getting the data types of the columns
data.dtypes
# Out:
# manufacturer_name     object
# model_name            object
# transmission          object
# color                 object
# odometer_value         int64
# year_produced          int64
# engine_fuel           object
# engine_has_gas          bool
# engine_type           object
# engine_capacity      float64
# body_type             object
# has_warranty            bool
# state                 object
# drivetrain            object
# price_usd            float64
# is_exchangeable         bool
# location_region       object
# number_of_photos       int64
# up_counter             int64
# feature_0               bool
# feature_1               bool
# feature_2               bool
# feature_3               bool
# feature_4               bool
# feature_5               bool
# feature_6               bool
# feature_7               bool
# feature_8               bool
# feature_9               bool
# duration_listed        int64
# dtype: object

# %%
#dropping irrelevant columns
data = data.drop(['engine_has_gas', 'feature_1', 'feature_2', 'feature_3', 'feature_4', 'feature_5', 'feature_6', 'feature_7', 'feature_8', 'feature_9', 'location_region'], 
             axis=1)

# %%
data
# Out:
#       manufacturer_name  model_name transmission   color  odometer_value  \
# 0                Subaru     Outback    automatic  silver          190000
# 1                Subaru     Outback    automatic    blue          290000
# 2                Subaru    Forester    automatic     red          402000
# 3                Subaru     Impreza   mechanical    blue           10000
# 4                Subaru      Legacy    automatic   black          280000
# ...                 ...         ...          ...     ...             ...
# 38526          Chrysler         300    automatic  silver          290000
# 38527          Chrysler  PT Cruiser   mechanical    blue          321000
# 38528          Chrysler         300    automatic    blue          777957
# 38529          Chrysler  PT Cruiser   mechanical   black           20000
# 38530          Chrysler     Voyager    automatic  silver          297729
#
#        year_produced engine_fuel engine_type  engine_capacity  body_type  \
# ...

# %%
#reviewing top rows
data.head()
# Out:
#   manufacturer_name model_name transmission   color  odometer_value  \
# 0            Subaru    Outback    automatic  silver          190000
# 1            Subaru    Outback    automatic    blue          290000
# 2            Subaru   Forester    automatic     red          402000
# 3            Subaru    Impreza   mechanical    blue           10000
# 4            Subaru     Legacy    automatic   black          280000
#
#    year_produced engine_fuel engine_type  engine_capacity  body_type  \
# 0           2010    gasoline    gasoline              2.5  universal
# 1           2002    gasoline    gasoline              3.0  universal
# 2           2001    gasoline    gasoline              2.5        suv
# 3           1999    gasoline    gasoline              3.0      sedan
# 4           2001    gasoline    gasoline              2.5  universal
#
#    has_warranty  state drivetrain  price_usd  is_exchangeable  \
# 0         False  owned        all   10900.00            False
# ...

# %%
#renaming the columns
data=data.rename(columns= {'manufacturer_name': 'manufacturer', 'model_name': 'model'})

# %%
data.head()
# Out:
#   manufacturer     model transmission   color  odometer_value  year_produced  \
# 0       Subaru   Outback    automatic  silver          190000           2010
# 1       Subaru   Outback    automatic    blue          290000           2002
# 2       Subaru  Forester    automatic     red          402000           2001
# 3       Subaru   Impreza   mechanical    blue           10000           1999
# 4       Subaru    Legacy    automatic   black          280000           2001
#
#   engine_fuel engine_type  engine_capacity  body_type  has_warranty  state  \
# 0    gasoline    gasoline              2.5  universal         False  owned
# 1    gasoline    gasoline              3.0  universal         False  owned
# 2    gasoline    gasoline              2.5        suv         False  owned
# 3    gasoline    gasoline              3.0      sedan         False  owned
# 4    gasoline    gasoline              2.5  universal         False  owned
#
# ...

# %%
#dropping the duplicate rows
data.shape
# Out:
# (38531, 19)

# %%
duplicate_rows_data = df[data.duplicated()]
print("number of duplicate rows:", duplicate_rows_data.shape)
# Out:
# number of duplicate rows: (41, 30)

# %%
data.count()
# Out:
# manufacturer        38531
# model               38531
# transmission        38531
# color               38531
# odometer_value      38531
# year_produced       38531
# engine_fuel         38531
# engine_type         38531
# engine_capacity     38521
# body_type           38531
# has_warranty        38531
# state               38531
# drivetrain          38531
# price_usd           38531
# is_exchangeable     38531
# number_of_photos    38531
# up_counter          38531
# feature_0           38531
# duration_listed     38531
# dtype: int64

# %%
data = data.drop_duplicates()
data.head()
# Out:
#   manufacturer     model transmission   color  odometer_value  year_produced  \
# 0       Subaru   Outback    automatic  silver          190000           2010
# 1       Subaru   Outback    automatic    blue          290000           2002
# 2       Subaru  Forester    automatic     red          402000           2001
# 3       Subaru   Impreza   mechanical    blue           10000           1999
# 4       Subaru    Legacy    automatic   black          280000           2001
#
#   engine_fuel engine_type  engine_capacity  body_type  has_warranty  state  \
# 0    gasoline    gasoline              2.5  universal         False  owned
# 1    gasoline    gasoline              3.0  universal         False  owned
# 2    gasoline    gasoline              2.5        suv         False  owned
# 3    gasoline    gasoline              3.0      sedan         False  owned
# 4    gasoline    gasoline              2.5  universal         False  owned
#
# ...

# %%
data.count()
# Out:
# manufacturer        38490
# model               38490
# transmission        38490
# color               38490
# odometer_value      38490
# year_produced       38490
# engine_fuel         38490
# engine_type         38490
# engine_capacity     38480
# body_type           38490
# has_warranty        38490
# state               38490
# drivetrain          38490
# price_usd           38490
# is_exchangeable     38490
# number_of_photos    38490
# up_counter          38490
# feature_0           38490
# duration_listed     38490
# dtype: int64

# %%
#counting the missing values
print(data.isnull().sum())
# Out:
# manufacturer         0
# model                0
# transmission         0
# color                0
# odometer_value       0
# year_produced        0
# engine_fuel          0
# engine_type          0
# engine_capacity     10
# body_type            0
# has_warranty         0
# state                0
# drivetrain           0
# price_usd            0
# is_exchangeable      0
# number_of_photos     0
# up_counter           0
# feature_0            0
# duration_listed      0
# dtype: int64

# %%
#dropping the missing values
data = data.dropna()
data.count()
# Out:
# manufacturer        38480
# model               38480
# transmission        38480
# color               38480
# odometer_value      38480
# year_produced       38480
# engine_fuel         38480
# engine_type         38480
# engine_capacity     38480
# body_type           38480
# has_warranty        38480
# state               38480
# drivetrain          38480
# price_usd           38480
# is_exchangeable     38480
# number_of_photos    38480
# up_counter          38480
# feature_0           38480
# duration_listed     38480
# dtype: int64

# %%
#checking again for null values
print(data.isnull().sum())
# Out:
# manufacturer        0
# model               0
# transmission        0
# color               0
# odometer_value      0
# year_produced       0
# engine_fuel         0
# engine_type         0
# engine_capacity     0
# body_type           0
# has_warranty        0
# state               0
# drivetrain          0
# price_usd           0
# is_exchangeable     0
# number_of_photos    0
# up_counter          0
# feature_0           0
# duration_listed     0
# dtype: int64

# %%
#detecting outliers using IQR score technique

sns.boxplot(x=data['engine_capacity'])
# Out:
# <AxesSubplot:xlabel='engine_capacity'>

# %%
sns.boxplot(x=data['odometer_value'])
# Out:
# <AxesSubplot:xlabel='odometer_value'>

# %%
sns.boxplot(x=data['price_usd'])
# Out:
# <AxesSubplot:xlabel='price_usd'>

# %%
#total number of cars manufactured per make
data.manufacturer.value_counts().nlargest(40).plot(kind= "bar", figsize=(10,5))
plt.title("Number of cars by manufacturer")
plt.ylabel('Number of cars')
plt.xlabel('manufacturer');

# %%
#Noting relationships between variables using heatmaps
plt.figure(figsize=(10,5))
data_corr=data.corr()
sns.heatmap(data_corr,cmap="BrBG", annot=True)
data_corr
# Out:
#                   odometer_value  year_produced  engine_capacity  \
# odometer_value          1.000000      -0.487094         0.104790
# year_produced          -0.487094       1.000000         0.006157
# engine_capacity         0.104790       0.006157         1.000000
# has_warranty           -0.182399       0.201641        -0.051314
# price_usd              -0.419863       0.704927         0.297760
# is_exchangeable         0.044512      -0.060329         0.082418
# number_of_photos       -0.142419       0.257065         0.107239
# up_counter             -0.021474       0.008476         0.078997
# feature_0               0.108927      -0.350985        -0.141314
# duration_listed        -0.001499      -0.015891         0.079753
#
#                   has_warranty  price_usd  is_exchangeable  number_of_photos  \
# odometer_value       -0.182399  -0.419863         0.044512         -0.142419
# year_produced         0.201641   0.704927        -0.060329          0.257065
# ...

# %%
#correlation between engine capacity and Price
fig,ax = plt.subplots(figsize= (10 , 6))
ax.scatter(df["engine_capacity"], df["price_usd"])
ax.set_xlabel('engine_capacity')
ax.set_ylabel('price_usd')
plt.show()

# %%
#correlation between odometer and price
fig,ax = plt.subplots(figsize= (10 , 6))
ax.scatter(df["odometer_value"], df["price_usd"])
ax.set_xlabel('odometer_value')
ax.set_ylabel('price_usd')
plt.show()
